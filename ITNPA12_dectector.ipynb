# %%
# Run once. Restart the kernel after this cell completes.
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install -q ultralytics          # YOLOv8
# !pip install -q facenet-pytorch      # MTCNN face detector
# !pip install -q mediapipe            # 468-point face mesh
# !pip install -q albumentations       # augmentation pipeline
# !pip install -q opencv-python        # cv2
# !pip install -q scikit-learn         # classification_report

print('All dependencies installed. Restart the kernel now, then run from Cell 2.')
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\HP\AppData\Roaming\Python\Python313\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# All dependencies installed. Restart the kernel now, then run from Cell 2.
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
